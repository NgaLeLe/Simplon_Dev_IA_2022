# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # download des cascadeClassifier prétrainé s/
# # https://github.com/Itseez/opencv/tree/master/data/haarcascades
# mettre des fichier cascadeClassifier dans dossier et les importe

# %%
face_cascade = cv2.CascadeClassifier(
    'Detection de visages/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(
    'Detection de visages/haarcascade_eye.xml')

# %%
#lire photo

image = cv2.imread('Detection de visages/images/2tinder.png')
cv2.imshow('Photo', image)

# %%
type(gray_image)
# Out:
# numpy.ndarray

# %% [markdown]
# Detection de visages/images/dan.jpg

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(10,5))
plt.subplot(111)
plt.imshow(gray, cmap='gray')
plt.title("Photo d'original")
plt.axis('off');

# %%
faces = face_cascade.detectMultiScale(gray, 1.1, 9)

# %%
print("Affichage des visages trouvés")
if faces.size/4 != 2 :
    print("Image contient moins/plus 2 visages")
    exit
else :
    #recupere les coordonnées des visages detectés
    x1, y1, h1, w1 = faces[0]
    x2, y2, h2, w2 = faces[1]
    
    #slicing des images dans DF
# Out:
# Affichage des visages trouvés
# 318 66 108 108 320 387 94 94
