# %%
import pandas as pd

datapath = 'Jeux_de_donnees/'

# Load the data
startups = pd.read_csv(datapath + "50_Startups.csv")
startups.head(4)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.linear_model import SGDRegressor #module lineaire modele
from sklearn.model_selection import train_test_split 
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
#separer des donnees de la manière très facile


# Prepare the data 
#var predictif, var d'entree
X = np.c_[startups[["R&D Spend", "Administration", "Marketing Spend"]]]
y = np.c_[startups["Profit"]]

#preparation des données d'entrainement
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, random_state=0) #test_size = 0.4

X_valid, X_test, y_valid, y_test = train_test_split(
        X_test, y_test, test_size=0.5)

#visualisation
#startups.plot(kind='scatter', x="R&D Spend", y="Profit", color = "red")
#startups.plot(kind='scatter', x="Administration", y="Profit", color = "green")
#startups.plot(kind='scatter', x="Marketing Spend", y="Profit", color = "yellow")
#plt.show()

sns.pairplot(data=startups)
plt.show()

#
print("Information des Dataframe")
print("X,y shape ", X.shape, y.shape)

print("X,y train ", X_train.shape, y_train.shape)
print("X,y valid ", X_valid.shape, y_valid.shape)
print("X,y test ", X_test.shape, y_test.shape)
#applique regression lineaire
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X_train, y_train) #valeur alphar par défault est 0.5

#faire une prediction
X_new = [[	153441.51, 151377.59, 383199.62]]
print(model.predict(X_new))

"""
Information des Dataframe
X,y shape  (50, 3) (50, 1)
X,y train  (30, 3) (30, 1)
X,y valid  (10, 3) (10, 1)
X,y test  (10, 3) (10, 1)
[[182711.21578079]]
"""
# Out:
# Information des Dataframe
# X,y shape  (50, 3) (50, 1)
# X,y train  (30, 3) (30, 1)
# X,y valid  (10, 3) (10, 1)
# X,y test  (10, 3) (10, 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4f1eeaa1bc18> in <module>
#      41 print("X,y test ", X_test.shape, y_test.shape)
#      42 #applique regression lineaire
# ---> 43 model = sklearn.linear_model.LinearRegression()
#      44
#      45 # Train the model
#
# NameError: name 'sklearn' is not defined

# %%
#correlation d'entre des var
import matplotlib.pyplot as plt
correlation = startups.corr()
plt.figure()
plt.subplot(111)
sns.heatmap(correlation, annot=True, linewidths=1.0)
plt.show()

# %%
#preparation des données d'entrainement
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, random_state=0) #test_size = 0.4

X_valid, X_test, y_valid, y_test = train_test_split(
        X_test, y_test, test_size=0.5)

# %%
#select a linear model
model = make_pipeline(StandardScaler(), SGDRegressor(max_iter=1000, alpha=0.5)) #0.1 ou 0.5
#SGDRegressor modele ulitisé
#alpha: pas de calcul la desdence de
#max_iter: max de répète: il

#model = sklearn.linear_model.SGDRegressor()

#train the model
model.fit(X_train, y_train)
# Out:
# /home/simplon/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdregressor', SGDRegressor(alpha=0.5))])

# %%
#metric de perfomance
metric1 = {}

# %%
#faire la 2e modele (dimunie un var Adminis)
#calcul metric de performance de ce modele

# %%
#faire la 3e modele (enleve RD)
#metric de performance

# %%
 #met resultat 3 metric de performance dans DF
 #model 2 (enleve var Admis) r2_score est plus éleve 0.96 -> Adminis est un var bruit
